# %%
import pandas as pd

# %%
def unique(list1): 
  
    # intilize a null list 
    unique_list = [] 
      
    # traverse for all elements 
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x)

# %%
raw_df = pd.read_html("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Director")[2]

# %%
director_df = raw_df[raw_df["Year"]!=raw_df["Film"]]

# %%
list_of_years = director_df.Year.unique()

# %%
years = []
director=[]
film=[]
for x in list_of_years:
    years.append(director_df[director_df["Year"]==x].iloc[0]["Year"])
    director.append(director_df[director_df["Year"]==x].iloc[0]["Director(s)"])
    film.append(director_df[director_df["Year"]==x].iloc[0]["Film"])

# %%
bestdirector_df = pd.DataFrame({"Years": years, "Winner Name":director, "Film": film})

# %%
bestdirector_df
# Out:
#                      Years                       Winner Name  \
# 0            1927/28 (1st)  Frank Borzage (Dramatic Picture)
# 1   1928/1929(2nd)[note 1]                       Frank Lloyd
# 2           1929/1930(3rd)                   Lewis Milestone
# 3           1930/1931(4th)                     Norman Taurog
# 4           1931/1932(5th)                     Frank Borzage
# 5           1932/1933(6th)                       Frank Lloyd
# 6                1934(7th)                       Frank Capra
# 7                1935(8th)                         John Ford
# 8                1936(9th)                       Frank Capra
# 9               1937(10th)                       Leo McCarey
# 10              1938(11th)                       Frank Capra
# 11              1939(12th)                    Victor Fleming
# 12              1940(13th)                         John Ford
# 13              1941(14th)                         John Ford
# 14              1942(15th)                     William Wyler
# 15              1943(16th)                    Michael Curtiz
# 16              1944(17th)                       Leo McCarey
# 17              1945(18th)                      Billy Wilder
# 18              1946(19th)                     William Wyler
# 19              1947(20th)                        Elia Kazan
# 20              1948(21st)                       John Huston
# 21              1949(22nd)              Joseph L. Mankiewicz
# 22              1950(23rd)              Joseph L. Mankiewicz
# 23              1951(24th)                    George Stevens
# 24              1952(25th)                         John Ford
# 25              1953(26th)                    Fred Zinnemann
# 26              1954(27th)                        Elia Kazan
# 27              1955(28th)                      Delbert Mann
# 28              1956(29th)                    George Stevens
# 29              1957(30th)                        David Lean
# ..                     ...                               ...
# 62              1990(63rd)                     Kevin Costner
# 63              1991(64th)                    Jonathan Demme
# 64              1992(65th)                    Clint Eastwood
# 65              1993(66th)                  Steven Spielberg
# 66              1994(67th)                   Robert Zemeckis
# 67              1995(68th)                        Mel Gibson
# 68              1996(69th)                 Anthony Minghella
# 69              1997(70th)                     James Cameron
# 70              1998(71st)                  Steven Spielberg
# 71              1999(72nd)                        Sam Mendes
# 72              2000(73rd)                 Steven Soderbergh
# 73              2001(74th)                        Ron Howard
# 74              2002(75th)                    Roman Polanski
# 75              2003(76th)                     Peter Jackson
# 76              2004(77th)                    Clint Eastwood
# 77              2005(78th)                           Ang Lee
# 78              2006(79th)                   Martin Scorsese
# 79              2007(80th)                     Coen Brothers
# 80              2008(81st)                       Danny Boyle
# 81              2009(82nd)                   Kathryn Bigelow
# 82              2010(83rd)                        Tom Hooper
# 83              2011(84th)               Michel Hazanavicius
# 84              2012(85th)                           Ang Lee
# 85              2013(86th)                    Alfonso Cuarón
# 86              2014(87th)             Alejandro G. Iñárritu
# 87             2015 (88th)             Alejandro G. Iñárritu
# 88             2016 (89th)                   Damien Chazelle
# 89             2017 (90th)                Guillermo del Toro
# 90             2018 (91st)                    Alfonso Cuarón
# 91             2019 (92nd)                      Bong Joon-ho
#
#                                              Film
# 0                                      7th Heaven
# 1                                 The Divine Lady
# 2                  All Quiet on the Western Front
# 3                                          Skippy
# 4                                        Bad Girl
# 5                                       Cavalcade
# 6                           It Happened One Night
# 7                                    The Informer
# 8                          Mr. Deeds Goes to Town
# 9                                 The Awful Truth
# 10                     You Can't Take It with You
# 11                             Gone with the Wind
# 12                            The Grapes of Wrath
# 13                        How Green Was My Valley
# 14                                   Mrs. Miniver
# 15                                     Casablanca
# 16                                   Going My Way
# 17                               The Lost Weekend
# 18                    The Best Years of Our Lives
# 19                          Gentleman's Agreement
# 20               The Treasure of the Sierra Madre
# 21                        A Letter to Three Wives
# 22                                  All About Eve
# 23                             A Place in the Sun
# 24                                  The Quiet Man
# 25                          From Here to Eternity
# 26                              On the Waterfront
# 27                                          Marty
# 28                                          Giant
# 29                   The Bridge on the River Kwai
# ..                                            ...
# 62                             Dances with Wolves
# 63                       The Silence of the Lambs
# 64                                     Unforgiven
# 65                               Schindler's List
# 66                                   Forrest Gump
# 67                                     Braveheart
# 68                            The English Patient
# 69                                        Titanic
# 70                            Saving Private Ryan
# 71                                American Beauty
# 72                                        Traffic
# 73                               A Beautiful Mind
# 74                                    The Pianist
# 75  The Lord of the Rings: The Return of the King
# 76                            Million Dollar Baby
# 77                             Brokeback Mountain
# 78                                   The Departed
# 79                         No Country for Old Men
# 80                            Slumdog Millionaire
# 81                                The Hurt Locker
# 82                              The King's Speech
# 83                                     The Artist
# 84                                     Life of Pi
# 85                                        Gravity
# 86                                        Birdman
# 87                                   The Revenant
# 88                                     La La Land
# 89                             The Shape of Water
# 90                                           Roma
# 91                                       Parasite
#
# [92 rows x 3 columns]

# %%
directors = []

for i in director:
    directors.append(i.split("&"))

# %%
directors
# Out:
# [['Frank Borzage (Dramatic Picture)'],
#  ['Frank Lloyd'],
#  ['Lewis Milestone'],
#  ['Norman Taurog'],
#  ['Frank Borzage'],
#  ['Frank Lloyd'],
#  ['Frank Capra'],
#  ['John Ford'],
#  ['Frank Capra'],
#  ['Leo McCarey'],
#  ['Frank Capra'],
#  ['Victor Fleming'],
#  ['John Ford'],
#  ['John Ford'],
#  ['William Wyler'],
#  ['Michael Curtiz'],
#  ['Leo McCarey'],
#  ['Billy Wilder'],
#  ['William Wyler'],
#  ['Elia Kazan'],
#  ['John Huston'],
#  ['Joseph L. Mankiewicz'],
#  ['Joseph L. Mankiewicz'],
#  ['George Stevens'],
#  ['John Ford'],
#  ['Fred Zinnemann'],
#  ['Elia Kazan'],
#  ['Delbert Mann'],
#  ['George Stevens'],
#  ['David Lean'],
#  ['Vincente Minnelli'],
#  ['William Wyler'],
#  ['Billy Wilder'],
#  ['Robert Wise ', ' Jerome Robbins'],
#  ['David Lean'],
#  ['Tony Richardson'],
#  ['George Cukor'],
#  ['Robert Wise'],
#  ['Fred Zinnemann'],
#  ['Mike Nichols'],
#  ['Carol Reed'],
#  ['John Schlesinger'],
#  ['Franklin J. Schaffner'],
#  ['William Friedkin'],
#  ['Bob Fosse'],
#  ['George Roy Hill'],
#  ['Francis Ford Coppola'],
#  ['Miloš Forman'],
#  ['John G. Avildsen'],
#  ['Woody Allen'],
#  ['Michael Cimino'],
#  ['Robert Benton'],
#  ['Robert Redford'],
#  ['Warren Beatty'],
#  ['Richard Attenborough'],
#  ['James L. Brooks'],
#  ['Miloš Forman'],
#  ['Sydney Pollack'],
#  ['Oliver Stone'],
#  ['Bernardo Bertolucci'],
#  ['Barry Levinson'],
#  ['Oliver Stone'],
#  ['Kevin Costner'],
#  ['Jonathan Demme'],
#  ['Clint Eastwood'],
#  ['Steven Spielberg'],
#  ['Robert Zemeckis'],
#  ['Mel Gibson'],
#  ['Anthony Minghella'],
#  ['James Cameron'],
#  ['Steven Spielberg'],
#  ['Sam Mendes'],
#  ['Steven Soderbergh'],
#  ['Ron Howard'],
#  ['Roman Polanski'],
#  ['Peter Jackson'],
#  ['Clint Eastwood'],
#  ['Ang Lee'],
#  ['Martin Scorsese'],
#  ['Coen Brothers'],
#  ['Danny Boyle'],
#  ['Kathryn Bigelow'],
#  ['Tom Hooper'],
#  ['Michel Hazanavicius'],
#  ['Ang Lee'],
#  ['Alfonso Cuarón'],
#  ['Alejandro G. Iñárritu'],
#  ['Alejandro G. Iñárritu'],
#  ['Damien Chazelle'],
#  ['Guillermo del Toro'],
#  ['Alfonso Cuarón'],
#  ['Bong Joon-ho']]
