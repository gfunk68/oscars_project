# %%
url = 'http://127.0.0.1:5000/api/v1.0/all_winners_data'

# %%
import pandas as pd

# %%
pd.read_json(url)
# Out:
#                                       _id     Year Oscar Year  \
# 0    {'$oid': '5e5196e0e3cd8c7adf34cda8'}  1927/28        1st
# 1    {'$oid': '5e5196e0e3cd8c7adf34cda9'}  1928/29        2nd
# 2    {'$oid': '5e5196e0e3cd8c7adf34cdaa'}  1929/30        3rd
# 3    {'$oid': '5e5196e0e3cd8c7adf34cdab'}  1930/31        4th
# 4    {'$oid': '5e5196e0e3cd8c7adf34cdac'}  1931/32        5th
# ..                                    ...      ...        ...
# 441  {'$oid': '5e5196e0e3cd8c7adf34cf61'}     2015       88th
# 442  {'$oid': '5e5196e0e3cd8c7adf34cf62'}     2016       89th
# 443  {'$oid': '5e5196e0e3cd8c7adf34cf63'}     2017       90th
# 444  {'$oid': '5e5196e0e3cd8c7adf34cf64'}     2018       91st
# 445  {'$oid': '5e5196e0e3cd8c7adf34cf65'}     2019       92nd
#
#                Winner Name                                               Film  \
# 0             Janet Gaynor  7th HeavenStreet AngelSunrise: A Song of Two H...
# ...
