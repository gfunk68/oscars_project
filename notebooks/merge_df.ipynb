# %%
import os
import pandas as pd
import sys
import json
import requests
from pprint import pprint
sys.path.insert(1, './')
from scraper import director,supporting_actor,supporting_actress,best_actor,best_actress

# %%
try:
    director_df = director()
except: 
    print("Oops!",sys.exc_info()[0],"occured, using bestdirector.csv instead")
    director_df = pd.Dataframe.read_csv("bestdirector.csv")
# Out:
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured

# %%
try:
    bestactor_df = best_actor()
except: 
    print("Oops!",sys.exc_info()[0],"occured, using bestactor.csv instead")
    bestactor_df = pd.Dataframe.read_csv("bestactor.csv")
# Out:
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured

# %%
try:
    bestactress_df = best_actress()
except: 
    print("Oops!",sys.exc_info()[0],"occured, using bestactress.csv instead")
    bestactress_df = pd.Dataframe.read_csv("bestactress.csv")
# Out:
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured

# %%
try:
    bestsupportingactor_df = supporting_actor()
except: 
    print("Oops!",sys.exc_info()[0],"occured, using bestsupportingactor.csv instead")
    bestsupportingactor_df = pd.Dataframe.read_csv("bestsupportingactor.csv")
# Out:
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured

# %%
try:
    bestsupportingactress_df = supporting_actress()
except: 
    print("Oops!",sys.exc_info()[0],"occured, using bestsupportingactress.csv instead")
    bestsupportingactress_df = pd.Dataframe.read_csv("bestsupportingactress.csv")
# Out:
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured

# %%
# # supportingActor_df.to_json()
# records = json.loads(supportingActor_df.to_json())
# records
allwinners_df = pd.concat([bestactress_df,bestactor_df,bestsupportingactor_df,bestsupportingactress_df,director_df], ignore_index=True)
# allwinners_df = pd.concat(allwinners_df, bestsupportingactor_df, ignore_index=True)
# allwinners_df = pd.concat(allwinners_df, bestsupportingactress_df, ignore_index=True)
# allwinners_df = pd.concat(allwinners_df, director_df, ignore_index=True)

# %%
allwinners_df.head(500)
# Out:
#         Year Oscar Year            Winner Name  \
# 0    1927/28        1st           Janet Gaynor
# 1    1928/29        2nd          Mary Pickford
# 2    1929/30        3rd          Norma Shearer
# 3    1930/31        4th         Marie Dressler
# 4    1931/32        5th            Helen Hayes
# ..       ...        ...                    ...
# 441     2015       88th  Alejandro G. Iñárritu
# 442     2016       89th        Damien Chazelle
# 443     2017       90th     Guillermo del Toro
# 444     2018       91st         Alfonso Cuarón
# 445     2019       92nd           Bong Joon-ho
#
#                                                   Film       Category  \
# 0    7th HeavenStreet AngelSunrise: A Song of Two H...   Best Actress
# 1                                             Coquette   Best Actress
# 2                                         The Divorcee   Best Actress
# 3                                         Min and Bill   Best Actress
# 4                           The Sin of Madelon Claudet   Best Actress
# ..                                                 ...            ...
# 441                                       The Revenant  Best Director
# 442                                         La La Land  Best Director
# 443                                 The Shape of Water  Best Director
# 444                                               Roma  Best Director
# 445                                           Parasite  Best Director
#
#                                               Wiki URL  \
# 0           https://en.wikipedia.org/wiki/Janet Gaynor
# 1          https://en.wikipedia.org/wiki/Mary Pickford
# 2          https://en.wikipedia.org/wiki/Norma Shearer
# 3         https://en.wikipedia.org/wiki/Marie Dressler
# 4            https://en.wikipedia.org/wiki/Helen Hayes
# ..                                                 ...
# 441  https://en.wikipedia.org/wiki/Alejandro G. Iñá...
# 442      https://en.wikipedia.org/wiki/Damien Chazelle
# 443   https://en.wikipedia.org/wiki/Guillermo del Toro
# 444       https://en.wikipedia.org/wiki/Alfonso Cuarón
# 445         https://en.wikipedia.org/wiki/Bong Joon-ho
#
#                          Birthplace Birth Year Age Awarded
# 0    Germantown, Pennsylvania, U.S.       1906          22
# 1          Toronto, Ontario, Canada       1892          37
# 2          Montreal, Quebec, Canada       1902          28
# 3          Cobourg, Ontario, Canada       1868          63
# 4            Washington, D.C., U.S.       1900          32
# ..                              ...        ...         ...
# 441             Mexico City, Mexico       1963          52
# 442  Providence, Rhode Island, U.S.       1985          31
# 443    Guadalajara, Jalisco, Mexico       1964          53
# 444             Mexico City, Mexico       1961          57
# 445              Daegu, South Korea       1969          50
#
# [446 rows x 9 columns]

# %%
from geopy import geocoders
gn = geocoders.GeoNames(username='gfunk68')

lat=[]
lon=[]



# base url by city name search
#https://samples.openweathermap.org/data/2.5/weather?q=London,uk&appid=b6907d289e10d714a6e88b30761fae22
base_url = "http://api.openweathermap.org/data/2.5/weather"
# dictionary to store query parameters
params={'appid':'f8b18b19cd1f9ce64f8f35d652b57a5f'}
params['q'] = "Düsseldorf, Prussia, German Empire"

for x in allwinners_df['Birthplace']:
    if x != 'Unknown':
        try:
            params['q']=x
            response = requests.get(base_url,params = params).json()
            lon.append(response['coord']['lon'])
            lat.append(response['coord']['lat'])
        except:
            try:
                y = gn.geocode(x)
                lat.append(y.latitude)
                lon.append(y.longitude)
            except:
                lat.append('Unknown')
                lon.append('Unknown')

    else:
        lat.append('Unknown')
        lon.append('Unknown')

allwinners_df['Birthplace Latitude'] = lat
allwinners_df['Birthplace Longitude'] = lon

# %%
allwinners_df.head(50)
# Out:
#        Year Oscar Year          Winner Name  \
# 0   1927/28        1st         Janet Gaynor
# 1   1928/29        2nd        Mary Pickford
# 2   1929/30        3rd        Norma Shearer
# 3   1930/31        4th       Marie Dressler
# 4   1931/32        5th          Helen Hayes
# 5   1932/33        6th    Katharine Hepburn
# 6      1934        7th    Claudette Colbert
# 7      1935        8th          Bette Davis
# 8      1936        9th         Luise Rainer
# 9      1937       10th         Luise Rainer
# 10     1938       11th          Bette Davis
# 11     1939       12th         Vivien Leigh
# 12     1940       13th        Ginger Rogers
# 13     1941       14th        Joan Fontaine
# 14     1942       15th         Greer Garson
# 15     1943       16th       Jennifer Jones
# 16     1944       17th       Ingrid Bergman
# 17     1945       18th        Joan Crawford
# 18     1946       19th  Olivia de Havilland
# 19     1947       20th        Loretta Young
# 20     1948       21st           Jane Wyman
# 21     1949       22nd  Olivia de Havilland
# 22     1950       23rd        Judy Holliday
# 23     1951       24th         Vivien Leigh
# 24     1952       25th        Shirley Booth
# 25     1953       26th       Audrey Hepburn
# 26     1954       27th          Grace Kelly
# 27     1955       28th         Anna Magnani
# 28     1956       29th       Ingrid Bergman
# 29     1957       30th      Joanne Woodward
# 30     1958       31st        Susan Hayward
# 31     1959       32nd      Simone Signoret
# 32     1960       33rd     Elizabeth Taylor
# 33     1961       34th         Sophia Loren
# 34     1962       35th        Anne Bancroft
# 35     1963       36th        Patricia Neal
