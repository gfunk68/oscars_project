# %%
#Import dependencies
import pandas as pd
import re
from bs4 import BeautifulSoup as bs
import requests
import sys
import os

# %%
#Import raw data from webpage
raw_df = pd.read_html("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Supporting_Actor")[2]

# %%
#Create List of unique oscar years
list_of_years = raw_df.Year.unique()

# %%
#Loop through the data to select only the Best Supporting Actor winners in each year. 
#Best Supporting Actor is always listed first in each Oscar year amongst the nominees.
years = []
supporting_actor=[]
film=[]

for x in list_of_years:
    years.append(raw_df[raw_df["Year"]==x].iloc[0]["Year"])
    supporting_actor.append(raw_df[raw_df["Year"]==x].iloc[0]["Actor"])
    film.append(raw_df[raw_df["Year"]==x].iloc[0]["Film"])

# %%
url=[]
for i in supporting_actor:
    url.append(f"https://en.wikipedia.org/wiki/{i}")

# %%
bestsupportingactor_df = pd.DataFrame({"Years": years, "Winner Name":supporting_actor, "Film": film,"Category":"BestSupportingActor","Wiki URL":url})

# %%
birthplace =[]
birthyear=[]



for x in url:
    response = requests.get(x)
    soup = bs(response.text, 'html.parser')
    try:
        birthplace_result = soup.find_all('div', class_='birthplace')[0].text
        birthplace.append(birthplace_result)
    except: 
        print("Oops!",sys.exc_info()[0],"occured")
        birthplace.append('Unknown')
    try:
        birthyear_result = soup.find_all('span', class_='bday')[0].text[:4]
        birthyear.append(birthyear_result)
    except:
        print("Oops!",sys.exc_info()[0],"occured")
        birthyear.append('Unknown')
# Out:
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured
# Oops! <class 'IndexError'> occured

# %%
bestsupportingactor_df['Birthplace']=birthplace
bestsupportingactor_df["Birth Year"]=birthyear
bestsupportingactor_df.to_csv("bestsupportingactor_df.csv",index=False)
bestsupportingactor_df.head(20)
# Out:
#           Years         Winner Name                              Film  \
# 0    1936 (9th)      Walter Brennan                   Come and Get It
# 1   1937 (10th)  Joseph Schildkraut            The Life of Emile Zola
# 2   1938 (11th)      Walter Brennan                          Kentucky
# 3   1939 (12th)     Thomas Mitchell                        Stagecoach
# 4   1940 (13th)      Walter Brennan                     The Westerner
# 5   1941 (14th)        Donald Crisp           How Green Was My Valley
# 6   1942 (15th)          Van Heflin                      Johnny Eager
# 7   1943 (16th)      Charles Coburn              The More the Merrier
# 8   1944 (17th)    Barry Fitzgerald                      Going My Way
# 9   1945 (18th)          James Dunn          A Tree Grows in Brooklyn
# 10  1946 (19th)      Harold Russell       The Best Years of Our Lives
# 11  1947 (20th)        Edmund Gwenn            Miracle on 34th Street
# 12  1948 (21st)       Walter Huston  The Treasure of the Sierra Madre
# 13  1949 (22nd)         Dean Jagger               Twelve O'Clock High
# 14  1950 (23rd)      George Sanders                     All About Eve
# 15  1951 (24th)         Karl Malden          A Streetcar Named Desire
# 16  1952 (25th)       Anthony Quinn                      Viva Zapata!
# 17  1953 (26th)       Frank Sinatra             From Here to Eternity
# 18  1954 (27th)      Edmond O'Brien             The Barefoot Contessa
# 19  1955 (28th)         Jack Lemmon                    Mister Roberts
#
#                Category                                          Wiki URL  \
# 0   BestSupportingActor      https://en.wikipedia.org/wiki/Walter Brennan
# 1   BestSupportingActor  https://en.wikipedia.org/wiki/Joseph Schildkraut
# 2   BestSupportingActor      https://en.wikipedia.org/wiki/Walter Brennan
# 3   BestSupportingActor     https://en.wikipedia.org/wiki/Thomas Mitchell
# 4   BestSupportingActor      https://en.wikipedia.org/wiki/Walter Brennan
# 5   BestSupportingActor        https://en.wikipedia.org/wiki/Donald Crisp
# 6   BestSupportingActor          https://en.wikipedia.org/wiki/Van Heflin
# 7   BestSupportingActor      https://en.wikipedia.org/wiki/Charles Coburn
# 8   BestSupportingActor    https://en.wikipedia.org/wiki/Barry Fitzgerald
# 9   BestSupportingActor          https://en.wikipedia.org/wiki/James Dunn
# 10  BestSupportingActor      https://en.wikipedia.org/wiki/Harold Russell
# 11  BestSupportingActor        https://en.wikipedia.org/wiki/Edmund Gwenn
# 12  BestSupportingActor       https://en.wikipedia.org/wiki/Walter Huston
# 13  BestSupportingActor         https://en.wikipedia.org/wiki/Dean Jagger
# 14  BestSupportingActor      https://en.wikipedia.org/wiki/George Sanders
# 15  BestSupportingActor         https://en.wikipedia.org/wiki/Karl Malden
# 16  BestSupportingActor       https://en.wikipedia.org/wiki/Anthony Quinn
# 17  BestSupportingActor       https://en.wikipedia.org/wiki/Frank Sinatra
# 18  BestSupportingActor      https://en.wikipedia.org/wiki/Edmond O'Brien
# 19  BestSupportingActor         https://en.wikipedia.org/wiki/Jack Lemmon
#
#                                Birthplace Birth Year
# 0               Lynn, Massachusetts, U.S.       1894
# 1   Vienna, Austria-Hungary (now Austria)       1896
# 2               Lynn, Massachusetts, U.S.       1894
# 3                                 Unknown    Unknown
# 4               Lynn, Massachusetts, U.S.       1894
# 5                Bow, London, England, UK       1882
# 6                 Walters, Oklahoma, U.S.       1908
# 7                    Macon, Georgia, U.S.       1877
# 8                         Dublin, Ireland       1888
# 9                                 Unknown    Unknown
# 10      North Sydney, Nova Scotia, Canada       1914
# 11              Wandsworth, London, UK[1]       1877
# 12               Toronto, Ontario, Canada       1883
# 13     Columbus Grove or Lima, Ohio, U.S.       1903
# 14       Saint Petersburg, Russian Empire       1906
# 15                Chicago, Illinois, U.S.       1912
# 16                      Chihuahua, Mexico       1915
# 17              Hoboken, New Jersey, U.S.       1915
# 18          New York City, New York, U.S.       1915
# 19            Newton, Massachusetts, U.S.       1925
